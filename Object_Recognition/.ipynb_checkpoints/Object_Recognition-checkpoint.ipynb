# %% [markdown]
# # Model Splitting

# %%
import tensorflow as tf
import keras
from keras.utils import to_categorical
from matplotlib import pyplot as plt
import numpy as np

# %%
(x_train,y_train),(x_test,y_test)=tf.keras.datasets.cifar10.load_data()

# %%
print('Training Images:{}'.format(x_train.shape))
print('Testing Images:{}'.format(x_test.shape))
# Out:
# Training Images:(50000, 32, 32, 3)
# Testing Images:(10000, 32, 32, 3)

# %%
print(x_train[0].shape)
# Out:
# (32, 32, 3)

# %%
plt.figure(figsize=(5,10))
for i in range (10):
    plt.subplot(5,2,i+1)
    img=x_train[i]
    plt.imshow(img)
plt.show()

# %% [markdown]
# # Preprocessing and One-Hot Encoding

# %%
x_train=x_train.reshape(x_train.shape[0],32,32,3)
x_test=x_test.reshape(x_test.shape[0],32,32,3)
x_train=x_train.astype('float32')
x_test=x_test.astype('float32')

# %%
x_train /= 255
x_test /= 255
n_classes=10

# %%
print("Shape before one-hot encoding: ", y_train.shape)
y_train=to_categorical(y_train,n_classes)
y_test=to_categorical(y_test,n_classes)
print("Shape after one-hot encoding: ", y_train.shape)
# Out:
# Shape before one-hot encoding:  (50000, 1)
# Shape after one-hot encoding:  (50000, 10)

# %% [markdown]
# # Model Compilation and Fitting

# %%
from keras.models import Sequential
from keras.layers import Dense,Dropout,Conv2D,MaxPool2D,Flatten

# %%
model=Sequential()
model.add(Conv2D(64, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu', input_shape=(32,32,3)))

model.add(Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3,3), strides=(1,1), padding='same', activation='relu'))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())

model.add(Dense(512,activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(512,activation='relu'))
model.add(Dropout(0.3))

model.add(Dense(10,activation='softmax'))

# %%
model.compile(optimizer='adam', loss="categorical_crossentropy", metrics=['accuracy'])

# %%
model.fit(x_train,y_train, batch_size=128, epochs=25, validation_data=(x_test,y_test))
# Out:
# Epoch 1/25
# 391/391 [==============================] - 964s 2s/step - loss: 1.8200 - accuracy: 0.3248 - val_loss: 1.1277 - val_accuracy: 0.6008
# Epoch 2/25
# 391/391 [==============================] - 818s 2s/step - loss: 1.1257 - accuracy: 0.5985 - val_loss: 1.0297 - val_accuracy: 0.6411
# Epoch 3/25
# 391/391 [==============================] - 803s 2s/step - loss: 0.9274 - accuracy: 0.6734 - val_loss: 0.8079 - val_accuracy: 0.7208
# Epoch 4/25
# 391/391 [==============================] - 705s 2s/step - loss: 0.7822 - accuracy: 0.7246 - val_loss: 0.7235 - val_accuracy: 0.7458
# Epoch 5/25
# 391/391 [==============================] - 770s 2s/step - loss: 0.7081 - accuracy: 0.7532 - val_loss: 0.7120 - val_accuracy: 0.7541
# Epoch 6/25
# 391/391 [==============================] - 742s 2s/step - loss: 0.6228 - accuracy: 0.7792 - val_loss: 0.6747 - val_accuracy: 0.7648
# Epoch 7/25
# 391/391 [==============================] - 662s 2s/step - loss: 0.5781 - accuracy: 0.7941 - val_loss: 0.6584 - val_accuracy: 0.7731
# Epoch 8/25
# 391/391 [==============================] - 774s 2s/step - loss: 0.5215 - accuracy: 0.8162 - val_loss: 0.6528 - val_accuracy: 0.7784
# Epoch 9/25
# 391/391 [==============================] - 638s 2s/step - loss: 0.4768 - accuracy: 0.8321 - val_loss: 0.6551 - val_accuracy: 0.7793
# Epoch 10/25
# 391/391 [==============================] - 795s 2s/step - loss: 0.4391 - accuracy: 0.8439 - val_loss: 0.6376 - val_accuracy: 0.7834
# Epoch 11/25
# 391/391 [==============================] - 748s 2s/step - loss: 0.4154 - accuracy: 0.8544 - val_loss: 0.6834 - val_accuracy: 0.7703
# Epoch 12/25
# 391/391 [==============================] - 843s 2s/step - loss: 0.3843 - accuracy: 0.8650 - val_loss: 0.6692 - val_accuracy: 0.7813
# Epoch 13/25
# 391/391 [==============================] - 734s 2s/step - loss: 0.3643 - accuracy: 0.8721 - val_loss: 0.6585 - val_accuracy: 0.7869
# Epoch 14/25
# 391/391 [==============================] - 753s 2s/step - loss: 0.3340 - accuracy: 0.8811 - val_loss: 0.6780 - val_accuracy: 0.7889
# Epoch 15/25
# 391/391 [==============================] - 880s 2s/step - loss: 0.3153 - accuracy: 0.8885 - val_loss: 0.6664 - val_accuracy: 0.7858
# Epoch 16/25
# 391/391 [==============================] - 823s 2s/step - loss: 0.3064 - accuracy: 0.8910 - val_loss: 0.7015 - val_accuracy: 0.7806
# Epoch 17/25
# 391/391 [==============================] - 702s 2s/step - loss: 0.2981 - accuracy: 0.8932 - val_loss: 0.6726 - val_accuracy: 0.7865
# Epoch 18/25
# 391/391 [==============================] - 812s 2s/step - loss: 0.2924 - accuracy: 0.8985 - val_loss: 0.6914 - val_accuracy: 0.7864
# Epoch 19/25
# 391/391 [==============================] - 792s 2s/step - loss: 0.2666 - accuracy: 0.9061 - val_loss: 0.6930 - val_accuracy: 0.7894
# Epoch 20/25
# 391/391 [==============================] - 688s 2s/step - loss: 0.2556 - accuracy: 0.9101 - val_loss: 0.6958 - val_accuracy: 0.7933
# Epoch 21/25
# 391/391 [==============================] - 638s 2s/step - loss: 0.2420 - accuracy: 0.9160 - val_loss: 0.6998 - val_accuracy: 0.7857
# Epoch 22/25
# 391/391 [==============================] - 711s 2s/step - loss: 0.2425 - accuracy: 0.9152 - val_loss: 0.7230 - val_accuracy: 0.7850
# Epoch 23/25
# 391/391 [==============================] - 772s 2s/step - loss: 0.2319 - accuracy: 0.9186 - val_loss: 0.7131 - val_accuracy: 0.7878
# Epoch 24/25
# 391/391 [==============================] - 792s 2s/step - loss: 0.2155 - accuracy: 0.9258 - val_loss: 0.6905 - val_accuracy: 0.7915
# Epoch 25/25
# 391/391 [==============================] - 762s 2s/step - loss: 0.2208 - accuracy: 0.9227 - val_loss: 0.7174 - val_accuracy: 0.7917

# %% [markdown]
# # Model Prediction

# %%
classes = range(0,10)
names=['airplane',
       'automobile',
       'bird',
       'cat',
       'deer',
       'dog',
       'frog',
       'horse',
       'ship',
       'truck']

# %%
class_labels=dict(zip(classes,names))
batch=x_test[100:109]
labels=np.argmax(y_test[100:109],axis=-1)

# %%
predictions=model.predict(batch,verbose=1)
# Out:
# 1/1 [==============================] - 0s 345ms/step

# %%
class_result=np.argmax(predictions,axis=-1)
print(class_result)
# Out:
# [4 5 6 3 1 1 3 6 8]

# %%
fig,axs=plt.subplots(3,3,figsize=(19,6))
fig.subplots_adjust(hspace=1)
axs=axs.flatten()

for i,img in enumerate(batch):
    for key,value in class_labels.items():
        if class_result[i]==key:
            title="Prediction: {}\n Actual: {}".format(class_labels[key],class_labels[labels[i]])
            axs[i].set_title(title)
            axs[i].axes.get_xaxis().set_visible(False)
            axs[i].axes.get_yaxis().set_visible(False)
            
    axs[i].imshow(img)

plt.show()
